# %% [markdown]
# # Analyzing document layout
# 1. DIA bounding boxes (with pretrained model)
# 2. OCR text inside boxes (with Tessaract client)
# 3. Structure output as tabluar
# 4. (NER on output)
#
# Tutorial: https://towardsdatascience.com/analyzing-document-layout-with-layoutparser-ed24d85f1d44
#
# To do:
# - [ ] tune best layout model so that each box is one text field
# - [ ] set up environment with Tesseract-OCR engine on Great Lakes
# - [ ] put scans on Great Lakes Turbo

# %%
import layoutparser as lp
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import numpy as np
import cv2

# %% [markdown]
# Load image

# %%
image = cv2.imread('../scans/274-01-0001.jpg')
plt.imshow(image);

# %% [markdown]
# Detect layout
# * [Model catalog](https://layout-parser.readthedocs.io/en/latest/notes/modelzoo.html#model-catalog): Prima layout is best approximation for irregular index card layout
#
# Inspect bounding boxes detected on scan
# - coordinates of the bounding box (x1, y1, x2, y2) of each detected layout
# - type of detected layout (i.e text, image, table, list, or title)
# - id of detected layout
# - text inside each detected layout
# - confidence score of each detected layout

# %%
# prima layout
model = lp.Detectron2LayoutModel('lp://PrimaLayout/mask_rcnn_R_50_FPN_3x/config', 
                                 label_map = {1:"TextRegion", 2:"ImageRegion", 3:"TableRegion", 4:"MathsRegion", 5:"SeparatorRegion", 6:"OtherRegion"},
                                 extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.1] # Optional
)

layout_result = model.detect(image)
print(layout_result)
lp.draw_box(image, layout_result,  box_width=5, box_alpha=0.2, show_element_type=True)
# Out:
# The checkpoint state_dict contains keys that are not used by the model:
#   pixel_mean
#   pixel_std
#   proposal_generator.anchor_generator.cell_anchors.{0, 1, 2, 3, 4}
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=361.6532287597656, y_1=569.1644897460938, x_2=818.7578735351562, y_2=609.4520263671875), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.9489332437515259), TextBlock(block=Rectangle(x_1=192.7593994140625, y_1=572.1420288085938, x_2=431.7569274902344, y_2=608.3895874023438), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.9181948304176331), TextBlock(block=Rectangle(x_1=78.29737854003906, y_1=566.7936401367188, x_2=612.7144775390625, y_2=610.3745727539062), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.6648922562599182), TextBlock(block=Rectangle(x_1=0.0, y_1=49.22517395019531, x_2=1174.490478515625, y_2=333.7599182128906), text=None, id=None, type=ImageRegion, parent=None, next=None, score=0.5900176763534546), TextBlock(block=Rectangle(x_1=1184.549560546875, y_1=44.08863067626953, x_2=1425.22119140625, y_2=267.8226318359375), text=None, id=None, type=OtherRegion, parent=None, next=None, score=0.5173063278198242), TextBlock(block=Rectangle(x_1=25.497709274291992, y_1=91.24178314208984, x_2=1324.1043701171875, y_2=393.5873718261719), text=None, id=None, type=OtherRegion, parent=None, next=None, score=0.24531356990337372), TextBlock(block=Rectangle(x_1=372.2296447753906, y_1=341.7650146484375, x_2=1373.1510009765625, y_2=446.4222412109375), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.2211892008781433), TextBlock(block=Rectangle(x_1=1193.261962890625, y_1=56.3626708984375, x_2=1412.56396484375, y_2=261.814697265625), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.13747966289520264), TextBlock(block=Rectangle(x_1=52.6122932434082, y_1=509.7132263183594, x_2=179.22161865234375, y_2=624.07666015625), text=None, id=None, type=ImageRegion, parent=None, next=None, score=0.10420138388872147)], page_data={})
# <PIL.Image.Image image mode=RGB size=1495x923 at 0x7FAB008126D8>

# %% [markdown]
# Optional: Get specific text blocks

# %%
text_blocks = lp.Layout([b for b in layout_result if b.type=='TextRegion'])
print(text_blocks)
lp.draw_box(image, text_blocks,  box_width=5, box_alpha=0.2, show_element_type=True, show_element_id=True)
# Out:
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=361.6532287597656, y_1=569.1644897460938, x_2=818.7578735351562, y_2=609.4520263671875), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.9489332437515259), TextBlock(block=Rectangle(x_1=192.7593994140625, y_1=572.1420288085938, x_2=431.7569274902344, y_2=608.3895874023438), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.9181948304176331), TextBlock(block=Rectangle(x_1=78.29737854003906, y_1=566.7936401367188, x_2=612.7144775390625, y_2=610.3745727539062), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.6648922562599182), TextBlock(block=Rectangle(x_1=372.2296447753906, y_1=341.7650146484375, x_2=1373.1510009765625, y_2=446.4222412109375), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.2211892008781433), TextBlock(block=Rectangle(x_1=1193.261962890625, y_1=56.3626708984375, x_2=1412.56396484375, y_2=261.814697265625), text=None, id=None, type=TextRegion, parent=None, next=None, score=0.13747966289520264)], page_data={})
# <PIL.Image.Image image mode=RGB size=1495x923 at 0x7FAAFD3E2B70>

# %% [markdown]
# Sort text for OCR engine to extract sequentially

# %%
image_width = len(image[0])

# Sort element ID of the left column based on y1 coordinate
left_interval = lp.Interval(0, image_width/2, axis='x').put_on_canvas(image)
left_blocks = text_blocks.filter_by(left_interval, center=True)._blocks
left_blocks.sort(key = lambda b:b.coordinates[1])

# Sort element ID of the right column based on y1 coordinate
right_blocks = [b for b in text_blocks if b not in left_blocks]
right_blocks.sort(key = lambda b:b.coordinates[1])

# Sort the overall element ID starts from left column
text_blocks = lp.Layout([b.set(id = idx) for idx, b in enumerate(left_blocks + right_blocks)])

# %%
ocr_agent = lp.TesseractAgent(languages='eng')

# %%
# for block in text_blocks:

#     # Crop image around the detected layout
#     segment_image = (block
#                        .pad(left=15, right=15, top=5, bottom=5)
#                        .crop_image(image))
    
#     # Perform OCR
#     text = ocr_agent.detect(segment_image)

#     # Save OCR result
#     block.set(text=text, inplace=True)

# %%
text = ocr_agent.detect(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/miniconda3/envs/layout/lib/python3.6/site-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     251     try:
# --> 252         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     253     except OSError as e:
#
# ~/miniconda3/envs/layout/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# ~/miniconda3/envs/layout/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1363                             err_msg += ': ' + repr(err_filename)
# -> 1364                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1365                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tesseract': 'tesseract'
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# <ipython-input-43-34a1e1710be6> in <module>
# ----> 1 text = ocr_agent.detect(image)
#
# ~/miniconda3/envs/layout/lib/python3.6/site-packages/layoutparser/ocr/tesseract_agent.py in detect(self, image, return_response, return_only_text, agg_output_level)
#     120         """
#     121
# --> 122         res = self._detect(image)
#     123
#     124         if return_response:
#
# ~/miniconda3/envs/layout/lib/python3.6/site-packages/layoutparser/ocr/tesseract_agent.py in _detect(self, img_content)
#      88         res = {}
#      89         res["text"] = pytesseract.image_to_string(
# ---> 90             img_content, lang=self.lang, **self.configs
#      91         )
#      92         _data = pytesseract.image_to_data(img_content, lang=self.lang, **self.configs)
#
# ~/miniconda3/envs/layout/lib/python3.6/site-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     415         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     416         Output.STRING: lambda: run_and_get_output(*args),
# --> 417     }[output_type]()
#     418
#     419
#
# ~/miniconda3/envs/layout/lib/python3.6/site-packages/pytesseract/pytesseract.py in <lambda>()
#     414         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     415         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 416         Output.STRING: lambda: run_and_get_output(*args),
#     417     }[output_type]()
#     418
#
# ~/miniconda3/envs/layout/lib/python3.6/site-packages/pytesseract/pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     282         }
#     283
# --> 284         run_tesseract(**kwargs)
#     285         filename = kwargs['output_filename_base'] + extsep + extension
#     286         with open(filename, 'rb') as output_file:
#
# ~/miniconda3/envs/layout/lib/python3.6/site-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254         if e.errno != ENOENT:
#     255             raise e
# --> 256         raise TesseractNotFoundError()
#     257
#     258     with timeout_manager(proc, timeout) as error_string:
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.
